# %%
#!pip install skimpy

# %%
import pandas as pd
from skimpy import skim

# %% [markdown]
# ### Load the data

# %%
df = pd.read_csv("D:\\JOB ASSIGNMENT\\p1\\Data & Resources\\Data\\Customer_Data.csv")
df.head(5)
#skim(df)
# Out:
#   Customer_ID  Gender  Age Married        State  Number_of_Referrals  \
# 0   19877-DEL    Male   35      No        Delhi                    7
# 1   58353-MAH  Female   45     Yes  Maharashtra                   14
# 2   25063-WES    Male   51      No  West Bengal                    4
# 3   59787-KAR    Male   79      No    Karnataka                    3
# 4   28544-TAM  Female   80      No   Tamil Nadu                    3
#
#    Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# 0                27        NaN           Yes             No  ...
# 1                13        NaN           Yes            Yes  ...
# 2                35     Deal 5           Yes             No  ...
# 3                21     Deal 4           Yes             No  ...
# 4                 8        NaN           Yes             No  ...
#
#     Payment_Method Monthly_Charge Total_Charges Total_Refunds  \
# 0      Credit Card           65.6        593.30          0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  6418 non-null   object
#  1   Gender                       6418 non-null   object
#  2   Age                          6418 non-null   int64
#  3   Married                      6418 non-null   object
#  4   State                        6418 non-null   object
#  5   Number_of_Referrals          6418 non-null   int64
#  6   Tenure_in_Months             6418 non-null   int64
#  7   Value_Deal                   2870 non-null   object
#  8   Phone_Service                6418 non-null   object
#  9   Multiple_Lines               5796 non-null   object
#  10  Internet_Service             6418 non-null   object
#  11  Internet_Type                5028 non-null   object
#  12  Online_Security              5028 non-null   object
# ...

# %%
# GENDER PERCENTAGE %

Total_genders = df.groupby("Gender")["Gender"].count()

Total_count_of_genders = Total_genders.sum()

percentage_ratio = (Total_genders/Total_count_of_genders)*100

gender_stats = Total_genders.to_frame(name="Total Genders")
gender_stats["Percentage"] = percentage_ratio

percentage_genders = gender_stats.reset_index()
percentage_genders
# Out:
#    Gender  Total Genders  Percentage
# 0  Female           4048   63.072608
# 1    Male           2370   36.927392

# %%
# Contract PERCENTAGE %

Total_Contract = df.groupby("Contract")["Contract"].count()

Total_count_of_Contract = Total_Contract.sum()

percentage_ratio = (Total_Contract/Total_count_of_Contract)*100

Contract_stats = Total_Contract.to_frame(name="Total Contract")
Contract_stats["Percentage"] = percentage_ratio

percentage_Contract = Contract_stats.reset_index()
percentage_Contract
# Out:
#          Contract  Total Contract  Percentage
# 0  Month-to-Month            3286   51.199751
# 1        One Year            1413   22.016204
# 2        Two Year            1719   26.784045

# %%
# State PERCENTAGE %

Total_State = df.groupby("State")["State"].count()

Total_count_of_State = Total_State.sum()

percentage_ratio = (Total_State/Total_count_of_State)*100

State_stats = Total_State.to_frame(name="Total count of State")
State_stats["Percentage"] = percentage_ratio

percentage_State = State_stats.reset_index()
percentage_State = State_stats.sort_values(by="Total count of State", ascending= False)
percentage_State
# Out:
#                  Total count of State  Percentage
# State
# Uttar Pradesh                     629    9.800561
# Tamil Nadu                        600    9.348707
# Maharashtra                       504    7.852914
# Karnataka                         470    7.323154
# Haryana                           398    6.201309
# Andhra Pradesh                    395    6.154565
# West Bengal                       368    5.733873
# Punjab                            342    5.328763
# Bihar                             336    5.235276
# Gujarat                           335    5.219695
# Jammu & Kashmir                   320    4.985977
# Madhya Pradesh                    288    4.487379
# Telangana                         281    4.378311
# Rajasthan                         259    4.035525
# Kerala                            200    3.116236
# Odisha                            152    2.368339
# Assam                             139    2.165784
# Delhi                             127    1.978810
# ...

# %%
# Customer Status PERCENTAGE %

grouped = df.groupby('Customer_Status').agg(
    TotalCount=('Customer_Status', 'count'),
    TotalRev=('Total_Revenue', 'sum')
).reset_index()

# Step 3: Calculate the total revenue for all statuses
total_revenue = df['Total_Revenue'].sum()

# Step 4: Calculate the revenue percentage for each status
grouped['RevPercentage'] = (grouped['TotalRev'] / total_revenue) * 100
grouped
# Out:
#   Customer_Status  TotalCount     TotalRev  RevPercentage
# 0         Churned        1732   3411960.58      17.522943
# 1          Joined         411     49281.56       0.253097
# 2          Stayed        4275  16010148.27      82.223960

# %% [markdown]
# #

# %% [markdown]
# ### Explore and Clean

# %%
df.isnull().sum()
# Out:
# Customer_ID                       0
# Gender                            0
# Age                               0
# Married                           0
# State                             0
# Number_of_Referrals               0
# Tenure_in_Months                  0
# Value_Deal                     3548
# Phone_Service                     0
# Multiple_Lines                  622
# Internet_Service                  0
# Internet_Type                  1390
# Online_Security                1390
# Online_Backup                  1390
# Device_Protection_Plan         1390
# Premium_Support                1390
# Streaming_TV                   1390
# Streaming_Movies               1390
# Streaming_Music                1390
# Unlimited_Data                 1390
# Contract                          0
# Paperless_Billing                 0
# Payment_Method                    0
# Monthly_Charge                    0
# Total_Charges                     0
# Total_Refunds                     0
# ...

# %%
New_df = df.fillna({'Value_Deal': "None", 'Internet_Type': "None"})
New_df = df.fillna("No")
New_df.isnull().sum()
# Out:
# Customer_ID                    0
# Gender                         0
# Age                            0
# Married                        0
# State                          0
# Number_of_Referrals            0
# Tenure_in_Months               0
# Value_Deal                     0
# Phone_Service                  0
# Multiple_Lines                 0
# Internet_Service               0
# Internet_Type                  0
# Online_Security                0
# Online_Backup                  0
# Device_Protection_Plan         0
# Premium_Support                0
# Streaming_TV                   0
# Streaming_Movies               0
# Streaming_Music                0
# Unlimited_Data                 0
# Contract                       0
# Paperless_Billing              0
# Payment_Method                 0
# Monthly_Charge                 0
# Total_Charges                  0
# Total_Refunds                  0
# Total_Extra_Data_Charges       0
# Total_Long_Distance_Charges    0
# ...

# %%
#mapping
Customer_Status_map = {"Stayed":0, "Churned":1, "Joined": 2}

New_df["Customer_Status"] = New_df["Customer_Status"].map(Customer_Status_map)

df_joined = New_df[New_df['Customer_Status'] == 2]

# Filter DataFrame for 'Stayed' and 'Churned'
df_stayed_churned = New_df[New_df['Customer_Status'].isin([0, 1])]

# %%
df_joined
# Out:
#      Customer_ID  Gender  Age Married           State  Number_of_Referrals  \
# 17     93520-GUJ  Female   67      No         Gujarat                   13
# 23     57256-BIH  Female   18      No           Bihar                    9
# 48     72357-MAD  Female   53      No  Madhya Pradesh                   14
# 98     66612-KAR  Female   58     Yes       Karnataka                   11
# 104    22119-WES    Male   31     Yes     West Bengal                    5
# ...          ...     ...  ...     ...             ...                  ...
# 6333   31412-HAR  Female   81     Yes         Haryana                   14
# 6374   54997-UTT  Female   55      No   Uttar Pradesh                    7
# 6392   56728-RAJ    Male   40      No       Rajasthan                    0
# 6401   47624-TAM  Female   62     Yes      Tamil Nadu                    7
# 6406   95053-UTT  Female   32      No   Uttar Pradesh                   15
#
# ...

# %%
df_stayed_churned
# Out:
#      Customer_ID  Gender  Age Married          State  Number_of_Referrals  \
# 0      19877-DEL    Male   35      No          Delhi                    7
# 1      58353-MAH  Female   45     Yes    Maharashtra                   14
# 2      25063-WES    Male   51      No    West Bengal                    4
# 3      59787-KAR    Male   79      No      Karnataka                    3
# 4      28544-TAM  Female   80      No     Tamil Nadu                    3
# ...          ...     ...  ...     ...            ...                  ...
# 6413   43397-UTT  Female   41      No  Uttar Pradesh                    6
# 6414   22240-HAR    Male   51     Yes        Haryana                    0
# 6415   78682-KER  Female   65     Yes         Kerala                   14
# 6416   17816-ODI    Male   23      No         Odisha                    2
# 6417   34476-TAM    Male   73      No     Tamil Nadu                   13
#
#       Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# ...

# %%
df_joined.to_csv('D:\\JOB ASSIGNMENT\\df_joined.csv', index=False)

# %%
df_stayed_churned.to_csv('D:\\JOB ASSIGNMENT\\df_stayed_churned.csv', index=False)

# %%
New_df.to_csv('D:\\JOB ASSIGNMENT\\New_df.csv', index=False)
